# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import itertools
import pathlib
import warnings
from PIL import Image
from random import randint
warnings.filterwarnings('ignore')
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow import keras
from keras import layers
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D
from distutils.dir_util import copy_tree, remove_tree

import os
print(os.listdir("C:\\Users\\anany\Desktop\VIT\HACKATHONS\TINYHACK\LifeAI\\Dataset"))

print("TensorFlow Version:", tf.__version__)
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# TensorFlow Version: 2.11.0

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('C:\\Users\\anany\Desktop\VIT\HACKATHONS\TINYHACK\LifeAI\\Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))
# Out:
# Requirement already satisfied: split-folders in c:\users\anany\appdata\roaming\python\python38\site-packages (0.5.1)
# Copying files: 6400 files [01:09, 92.29 files/s]

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 5119 files belonging to 4 classes.
# Found 642 files belonging to 4 classes.
# Found 639 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [896,64,3200,2240]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model = keras.models.Sequential()
model.add(keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)))
model.add(keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))


model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64,"relu"))
model.add(keras.layers.Dense(4,"softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer = "Adam",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,129,380
# Trainable params: 2,129,380
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train_ds,validation_data=val_ds,epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 65s 768ms/step - loss: 1.4371 - accuracy: 0.4888 - val_loss: 1.0351 - val_accuracy: 0.5196
# Epoch 2/100
# 80/80 [==============================] - 60s 748ms/step - loss: 0.9481 - accuracy: 0.5521 - val_loss: 0.9086 - val_accuracy: 0.5837
# Epoch 3/100
# 80/80 [==============================] - 67s 836ms/step - loss: 0.8994 - accuracy: 0.5790 - val_loss: 0.8238 - val_accuracy: 0.6416
# Epoch 4/100
# 80/80 [==============================] - 72s 894ms/step - loss: 0.8276 - accuracy: 0.6257 - val_loss: 0.7923 - val_accuracy: 0.6244
# Epoch 5/100
# 80/80 [==============================] - 64s 791ms/step - loss: 0.7590 - accuracy: 0.6589 - val_loss: 0.6905 - val_accuracy: 0.7121
# Epoch 6/100
# 80/80 [==============================] - 67s 836ms/step - loss: 0.6649 - accuracy: 0.6999 - val_loss: 0.6492 - val_accuracy: 0.7308
# Epoch 7/100
# 80/80 [==============================] - 67s 836ms/step - loss: 0.5730 - accuracy: 0.7492 - val_loss: 0.5173 - val_accuracy: 0.7778
ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.0128 - val_accuracy: 0.9953
# Epoch 47/100
# 80/80 [==============================] - 61s 761ms/step - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.0168 - val_accuracy: 0.9953
# Epoch 48/100
# 80/80 [==============================] - 57s 704ms/step - loss: 0.0306 - accuracy: 0.9889 - val_loss: 0.0166 - val_accuracy: 0.9953
# Epoch 49/100
# 80/80 [==============================] - 58s 726ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0184 - val_accuracy: 0.9937
# Epoch 50/100
# 80/80 [==============================] - 56s 697ms/step - loss: 0.0230 - accuracy: 0.9916 - val_loss: 0.0176 - val_accuracy: 0.9937
# Epoch 51/100
# 80/80 [==============================] - 60s 748ms/step - loss: 0.0327 - accuracy: 0.9883 - val_loss: 0.0200 - val_accuracy: 0.9922
# Epoch 52/100
# 80/80 [==============================] - 59s 736ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.0078 - val_accuracy: 0.9984
# Epoch 53/100
# 80/80 [==============================] - 64s 795ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 0.0102 - val_accuracy: 0.9969
# Epoch 54/100
# 80/80 [==============================] - 65s 806ms/step - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.0168 - val_accuracy: 0.9953
# Epoch 55/100
# 80/80 [==============================] - 66s 830ms/step - loss: 0.0208 - accuracy: 0.9922 - val_loss: 0.0261 - val_accuracy: 0.9953
# Epoch 56/100
# 80/80 [==============================] - 63s 785ms/step - loss: 0.0251 - accuracy: 0.9920 - val_loss: 0.0160 - val_accuracy: 0.9937
# Epoch 57/100
# 80/80 [==============================] - 67s 834ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.0184 - val_accuracy: 0.9937
# Epoch 58/100
# 80/80 [==============================] - 62s 768ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.0339 - val_accuracy: 0.9859
# Epoch 59/100
# 80/80 [==============================] - 70s 873ms/step - loss: 0.0167 - accuracy: 0.9963 - val_loss: 0.0150 - val_accuracy: 0.9922
# Epoch 60/100
# 80/80 [==============================] - 72s 895ms/step - loss: 0.0210 - accuracy: 0.9912 - val_loss: 0.0344 - val_accuracy: 0.9875
# Epoch 61/100
# 80/80 [==============================] - 69s 865ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.0323 - val_accuracy: 0.9937
# Epoch 62/100
# 80/80 [==============================] - 72s 892ms/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.0295 - val_accuracy: 0.9922
# Epoch 63/100
# 80/80 [==============================] - 73s 913ms/step - loss: 0.0204 - accuracy: 0.9951 - val_loss: 0.0060 - val_accuracy: 0.9984
# Epoch 64/100
# 80/80 [==============================] - 72s 902ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 0.0194 - val_accuracy: 0.9953
# Epoch 65/100
# 80/80 [==============================] - 70s 871ms/step - loss: 0.0259 - accuracy: 0.9906 - val_loss: 0.0117 - val_accuracy: 0.9953
# Epoch 66/100
# 80/80 [==============================] - 80s 997ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0128 - val_accuracy: 0.9953
# Epoch 67/100
# 80/80 [==============================] - 79s 989ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0389 - val_accuracy: 0.9890
# Epoch 68/100
# 80/80 [==============================] - 72s 902ms/step - loss: 0.0244 - accuracy: 0.9916 - val_loss: 0.0209 - val_accuracy: 0.9922
# Epoch 69/100
# 80/80 [==============================] - 70s 876ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0196 - val_accuracy: 0.9953
# Epoch 70/100
# 80/80 [==============================] - 71s 882ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0184 - val_accuracy: 0.9922
# Epoch 71/100
# 80/80 [==============================] - 73s 906ms/step - loss: 0.0181 - accuracy: 0.9930 - val_loss: 0.0673 - val_accuracy: 0.9828
# Epoch 72/100
# 80/80 [==============================] - 74s 924ms/step - loss: 0.0296 - accuracy: 0.9908 - val_loss: 0.0141 - val_accuracy: 0.9953
# Epoch 73/100
# 80/80 [==============================] - 78s 975ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.0118 - val_accuracy: 0.9953
# Epoch 74/100
# 80/80 [==============================] - 77s 964ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0189 - val_accuracy: 0.9937
# Epoch 75/100
# 80/80 [==============================] - 75s 932ms/step - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.0180 - val_accuracy: 0.9937
# Epoch 76/100
# 80/80 [==============================] - 83s 1s/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.0232 - val_accuracy: 0.9906
# Epoch 77/100
# 80/80 [==============================] - 82s 1s/step - loss: 0.0170 - accuracy: 0.9937 - val_loss: 0.0335 - val_accuracy: 0.9890
# Epoch 78/100
# 80/80 [==============================] - 71s 885ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0289 - val_accuracy: 0.9922
# Epoch 79/100
# 80/80 [==============================] - 71s 890ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.0213 - val_accuracy: 0.9969
# Epoch 80/100
# 80/80 [==============================] - 76s 939ms/step - loss: 0.0259 - accuracy: 0.9920 - val_loss: 0.0250 - val_accuracy: 0.9906
# Epoch 81/100
# 80/80 [==============================] - 70s 874ms/step - loss: 0.0101 - accuracy: 0.9959 - val_loss: 0.0088 - val_accuracy: 0.9984
# Epoch 82/100
# 80/80 [==============================] - 70s 875ms/step - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.0071 - val_accuracy: 0.9969
# Epoch 83/100
# 80/80 [==============================] - 75s 933ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0225 - val_accuracy: 0.9922
# Epoch 84/100
# 80/80 [==============================] - 75s 933ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.0200 - val_accuracy: 0.9937
# Epoch 85/100
# 80/80 [==============================] - 69s 863ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 0.0092 - val_accuracy: 0.9969
# Epoch 86/100
# 80/80 [==============================] - 70s 868ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0273 - val_accuracy: 0.9937
# Epoch 87/100
# 80/80 [==============================] - 72s 896ms/step - loss: 0.0221 - accuracy: 0.9924 - val_loss: 0.0123 - val_accuracy: 0.9969
# Epoch 88/100
# 80/80 [==============================] - 78s 968ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.0090 - val_accuracy: 0.9953
# Epoch 89/100
# 80/80 [==============================] - 74s 916ms/step - loss: 0.0173 - accuracy: 0.9953 - val_loss: 0.0135 - val_accuracy: 0.9937
# Epoch 90/100
# 80/80 [==============================] - 89s 1s/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 0.0073 - val_accuracy: 0.9984
# Epoch 91/100
# 80/80 [==============================] - 80s 989ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 0.0092 - val_accuracy: 0.9969
# Epoch 92/100
# 80/80 [==============================] - 78s 965ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0143 - val_accuracy: 0.9937
# Epoch 93/100
# 80/80 [==============================] - 71s 889ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0102 - val_accuracy: 0.9953
# Epoch 94/100
# 80/80 [==============================] - 69s 862ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0186 - val_accuracy: 0.9922
# Epoch 95/100
# 80/80 [==============================] - 66s 821ms/step - loss: 0.0136 - accuracy: 0.9943 - val_loss: 0.0194 - val_accuracy: 0.9906
# Epoch 96/100
# 80/80 [==============================] - 67s 837ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.0259 - val_accuracy: 0.9890
# Epoch 97/100
# 80/80 [==============================] - 67s 832ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0072 - val_accuracy: 0.9969
# Epoch 98/100
# 80/80 [==============================] - 63s 791ms/step - loss: 0.0235 - accuracy: 0.9914 - val_loss: 0.0085 - val_accuracy: 0.9953
# Epoch 99/100
# 80/80 [==============================] - 64s 798ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.0041 - val_accuracy: 0.9984
# Epoch 100/100
# 80/80 [==============================] - 71s 881ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0133 - val_accuracy: 0.9969

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.title('Training data accuracy and loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_ac, 'g', label='Accuracy of Training Data')
plt.plot(epochs, val_acc, 'r', label='Accuracy of Validation Data')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_los, 'g', label='Loss of Training Data')
plt.plot(epochs, val_loss, 'r', label='Loss of Validation Data')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
loss, accuracy = model.evaluate(test_ds)
# Out:
# 11/11 [==============================] - 3s 158ms/step - loss: 0.0501 - accuracy: 0.9860

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'green'})
            
        else:
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])
# Out:
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
#from keras.models import load_model
model.save("alzheimersmine.h5")
